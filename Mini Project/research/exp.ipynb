# %%
import pandas as pd
import numpy as np
wine_df= pd.read_csv("WineQT.csv")
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wine_df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1138          False             False        False           False      False
# 1139          False             False        False           False      False
# 1140          False             False        False           False      False
# 1141          False             False        False           False      False
# 1142          False             False        False           False      False
#
# ...

# %%
wine_df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1138          False             False        False           False      False
# 1139          False             False        False           False      False
# 1140          False             False        False           False      False
# 1141          False             False        False           False      False
# 1142          False             False        False           False      False
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
wine_df.hist(bins = 10,figsize=(20,15), alpha =0.6)
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>,
#         <Axes: title={'center': 'residual sugar'}>],
#        [<Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>,
#         <Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>],
#        [<Axes: title={'center': 'pH'}>,
#         <Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>],
#        [<Axes: title={'center': 'Id'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
wine_df.columns.value_counts()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             1
# residual sugar          1
# chlorides               1
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               1
# alcohol                 1
# quality                 1
# Id                      1
# Name: count, dtype: int64

# %%
# Count missing values in each column
print(wine_df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(10,8))

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(wine_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = wine_df.drop('quality', axis=1)
Y = wine_df['quality']

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(X,Y)
#       3 plt.show()
#
# File ~/ML_Projects/.venv/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
wine_df['fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1138     6.3
# 1139     6.8
# 1140     6.2
# 1141     5.9
# 1142     5.9
# Name: fixed acidity, Length: 1143, dtype: float64

# %%
# Split the data into training and testing sets

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
# Display the shapes of the resulting datasets
print(X_train.shape)
print(X_test.shape)
# Out:
# (914, 12)
# (229, 12)

# %%
# Display the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (914, 12)
# X_test shape: (229, 12)
# Y_train shape: (914,)
# Y_test shape: (229,)

# %%
import matplotlib.pyplot as plt 
X,Y  = [1,2,3,4],[10,20,30,40]
plt.plot(X, Y)
plt.title('Simple Line ')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
from sklearn.linear_model import ElasticNet

# %%
lr = ElasticNet(alpha= 0.1, l1_ratio=0.5, random_state=42)
lr.fit(X_train, Y_train) 

print(lr.coef_)
print(lr.intercept_)
# Out:
# [ 4.04792797e-02 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  6.19227605e-03 -3.75252709e-03 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  3.07750458e-01 -7.02282318e-05]
# 2.2415362872632585

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 

#Predict the quality on test data
Y_Pred = lr.predict(X_test)

#calculate Mean Squared Error
mse = mean_squared_error(Y_test, Y_Pred)
print(f"Mean Squared Error: {mse}")

r1 = r2_score(Y_test, Y_Pred)
print(f"R-squared: {r1}")
# Out:
# Mean Squared Error: 0.39689490877304945
# R-squared: 0.2867669826959264

# %%
def eval_metrics(actual, pred):
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    r2 = r2_score(actual, pred)
    
    return mse, rmse, r2

# %%
predicated = lr.predict(X_test)

# %%
( rmse,mse,r2) = eval_metrics(Y_test, predicated)

# %%
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.629995959330732
# Root Mean Squared Error: 0.39689490877304945
# R-squared: 0.2867669826959264
